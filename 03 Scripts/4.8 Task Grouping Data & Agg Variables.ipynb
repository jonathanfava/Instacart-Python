# %% [markdown]
# ## Contents
#     4.8 Task questions

# %% [markdown]
# ### Q1.

# %%
# import libraries

import pandas as pd
import numpy as np
import os

# %%
# create path

path = r'/Users/jonathanfava/07-2022 Instacart Basket Analysis'

# %%
# import df from E4.8

ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_produts_E4.8'))

# %%
# check df

ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_day_of_week  time_of_order  ...  \
# 0   3139998      138            28                  6             11  ...
# 1   1977647      138            30                  6             17  ...
# 2    389851      709             2                  0             21  ...
# 3    652770      764             1                  3             13  ...
# 4   1813452      764             3                  4             17  ...
#
# ...

# %% [markdown]
# ### Q2.

# %%
# create a agg mean for order_number grouped by department_id for entire df

ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
#  ### Q3. The results are fairly similar with department 21 having the highest average value. But, the lowest average changed from department 12 in the subset to department 5.

# %% [markdown]
# ### Q4. Did this in the exercise

# %%
# to show lotalty_flag column added

ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_day_of_week  time_of_order  ...  \
# 0   3139998      138            28                  6             11  ...
# 1   1977647      138            30                  6             17  ...
# 2    389851      709             2                  0             21  ...
# 3    652770      764             1                  3             13  ...
# 4   1813452      764             3                  4             17  ...
#
# ...

# %% [markdown]
# ### Q5.

# %%
# statistics for loyalty categories

ords_prods_merge.groupby('loyalty_flag').agg({'prices':['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# ### Q6.

# %%
# create column for avg spent by customer

ords_prods_merge['avg_spent'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# check output

ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_day_of_week  time_of_order  ...  \
# 0   3139998      138            28                  6             11  ...
# 1   1977647      138            30                  6             17  ...
# 2    389851      709             2                  0             21  ...
# 3    652770      764             1                  3             13  ...
# 4   1813452      764             3                  4             17  ...
#
# ...

# %%
# create spending flag column

ords_prods_merge.loc[ords_prods_merge['avg_spent'] < 10, 'spending_flag'] = 'Low spender'
ords_prods_merge.loc[ords_prods_merge['avg_spent'] >= 10, 'spending_flag'] = 'High spender'

# %%
# check output

ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     31770614
# High spender      634245
# Name: spending_flag, dtype: int64

# %%
# check output

ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_day_of_week  time_of_order  ...  \
# 0   3139998      138            28                  6             11  ...
# 1   1977647      138            30                  6             17  ...
# 2    389851      709             2                  0             21  ...
# 3    652770      764             1                  3             13  ...
# 4   1813452      764             3                  4             17  ...
#
# ...

# %% [markdown]
# ### Q7.

# %%
pd.options.display.max_columns = None

# %%
# create column for median days since prior order 

ords_prods_merge['med_ord_freq'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# check output

ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_day_of_week  time_of_order  \
# 0   3139998      138            28                  6             11
# 1   1977647      138            30                  6             17
# 2    389851      709             2                  0             21
# 3    652770      764             1                  3             13
# 4   1813452      764             3                  4             17
#
#    days_since_prior_order  returning_customer  add_to_cart_order  reordered  \
# ...

# %%
# create frequency flag column

ords_prods_merge.loc[ords_prods_merge['med_ord_freq'] > 20, 'frequency_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['med_ord_freq'] <= 20) & (ords_prods_merge['med_ord_freq'] > 10), 'frequency_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['med_ord_freq'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
# check output

ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer    21559853
# Regular customer      7208564
# Loyal customer        3636437
# NaN                         5
# Name: frequency_flag, dtype: int64

# %%
# check output

ords_prods_merge.head(100)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# ..         ...                         ...       ...            ...     ...
# 95           1  Chocolate Sandwich Cookies        61             19     5.8
# 96           1  Chocolate Sandwich Cookies        61             19     5.8
# 97           1  Chocolate Sandwich Cookies        61             19     5.8
# 98           1  Chocolate Sandwich Cookies        61             19     5.8
# 99           1  Chocolate Sandwich Cookies        61             19     5.8
#
# ...

# %%
# export as pickle

ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_produts_grouped.pkl'))
