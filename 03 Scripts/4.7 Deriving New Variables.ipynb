# %% [markdown]
# ## Contents
#     4.7 Exercise

# %% [markdown]
# ## Import libraries and Data

# %%
# import libraries

import pandas as pd
import numpy as np
import os

# %%
# create path

path = r'/Users/jonathanfava/07-2022 Instacart Basket Analysis'

# %%
# import ords_prods_merged df

df_ords_prods = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'order_products_merged.pkl'))

# %%
# check df

df_ords_prods.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_day_of_week  time_of_order  \
# 0   3139998      138            28                  6             11
# 1   1977647      138            30                  6             17
# 2    389851      709             2                  0             21
# 3    652770      764             1                  3             13
# 4   1813452      764             3                  4             17
#
#    days_since_prior_order  returning_customer  add_to_cart_order  reordered  \
# ...

# %%
# define function

def add_num(x,y):
    sum = x + y
    return sum

# %%
# run function

add_num (9,11)
# Out:
# 20

# %%
# create subset with only 1 mil rows

df = df_ords_prods[:1000000]

# %%
df.shape
# Out:
# (1000000, 15)

# %% [markdown]
# ## if-statements

# %%
# define a function 

def price_label(row):

    if row['prices'] <= 5:
        return 'Low range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid range product'
    elif row['prices'] > 15:
        return 'High range product'
    else: return np.nan

# %%
# apply the function

df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/tj/p5nx3kt94l94591qjbcg_5mm0000gn/T/ipykernel_95249/2698948789.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
# checking the output

df['price_range'].value_counts(dropna = False)
# Out:
# Mid range product     652638
# Low range product     338018
# High range product      9344
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 24.5

# %% [markdown]
# ## if-statement with loc() function

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid range product     652638
# Low range product     338018
# High range product      9344
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ## if-statement with loc on full size df

# %%
df_ords_prods.loc[df_ords_prods['prices'] > 15, 'price_range_loc'] = 'High range product'

# %%
df_ords_prods.loc[(df_ords_prods['prices'] <= 15) & (df_ords_prods['prices'] > 5), 'price_range_loc'] = 'Mid range product'

# %%
df_ords_prods.loc[df_ords_prods['prices'] <= 5, 'price_range_loc'] = 'Low range product'

# %%
# check output
df_ords_prods['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid range product     21860860
# Low range product     10126321
# High range product      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ## if-statements with for-loops

# %%
df_ords_prods['order_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: order_day_of_week, dtype: int64

# %%
result = []

for value in df_ords_prods['order_day_of_week']:
    if value == 0:
        result.append('Busiest day')
    elif value == 4:
        result.append('Least busy')
    else:
        result.append('Regularly Busy')

# %%
result
# Out:
# ['Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Regularly Busy',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regularly Busy',
#  'Slowest days',
#  'Regularly Busy',
#  'Slowest days',
#  'Regularly Busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly Busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
# ...

# %%
df_ords_prods['busiest_day'] = result

# %%
df_ords_prods['busiest_day'].value_counts(dropna = False)
# Out:
# Slowest days      16326617
# Busiest days      11864412
# Regularly Busy     4213830
# Name: busiest_day, dtype: int64

# %% [markdown]
# ## Task Questions

# %% [markdown]
# # Q2.

# %%
# using for-loop to create client's requested changes to busiest days column

result2 = []

for value in df_ords_prods['order_day_of_week']:
    if value <= 1:
        result2.append('Busiest days')
    elif value >= 3:
        result2.append('Slowest days')
    else:
        result2.append('Regularly Busy')

# %%
# check result
result2
# Out:
# ['Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Regularly Busy',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regularly Busy',
#  'Slowest days',
#  'Regularly Busy',
#  'Slowest days',
#  'Regularly Busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly Busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
# ...

# %%
# apply results to df

df_ords_prods['busiest_days'] = result2

# %% [markdown]
# ## Q3.

# %%
# check new column

df_ords_prods['busiest_days'].value_counts(dropna = False)
# Out:
# Slowest days      16326617
# Busiest days      11864412
# Regularly Busy     4213830
# Name: busiest_days, dtype: int64

# %%
# check df

df_ords_prods
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404854       49688      Fresh Foaming Cleanser        73             11
# 32404855       49688      Fresh Foaming Cleanser        73             11
# 32404856       49688      Fresh Foaming Cleanser        73             11
# 32404857       49688      Fresh Foaming Cleanser        73             11
# 32404858       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  user_id  order_number  order_day_of_week  \
# ...

# %%
# drop columns due to creating muliple columns by mistake

df_new_ords_prods = df_ords_prods.drop(columns=['busiest_day', 'Busiest_days'])

# %%
# check results

df_new_ords_prods
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404854       49688      Fresh Foaming Cleanser        73             11
# 32404855       49688      Fresh Foaming Cleanser        73             11
# 32404856       49688      Fresh Foaming Cleanser        73             11
# 32404857       49688      Fresh Foaming Cleanser        73             11
# 32404858       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  user_id  order_number  order_day_of_week  \
# ...

# %% [markdown]
# ## Q4.

# %%
# find busiest period of day

df_new_ords_prods['time_of_order'].value_counts(dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: time_of_order, dtype: int64

# %%
# using for-loop to create busiest peroid of day column for client 

result3 = []

for value in df_new_ords_prods['time_of_order']:
    if value>=10 and value<=16:
        result3.append('Most Orders')
    elif value>=2 and value<=5:
        result3.append('Fewest Orders')
    else:
        result3.append('Average Orders')

# %%
result3
# Out:
# ['Most Orders',
#  'Average Orders',
#  'Average Orders',
#  'Most Orders',
#  'Average Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Fewest Orders',
#  'Average Orders',
#  'Fewest Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Average Orders',
#  'Most Orders',
#  'Average Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
# ...

# %%
# create new column and apply result

df_new_ords_prods['busiest_period_of_day'] = result3

# %%
# check 

df_new_ords_prods['busiest_period_of_day'].value_counts()
# Out:
# Most Orders       18663868
# Average Orders    13479132
# Fewest Orders       261859
# Name: busiest_period_of_day, dtype: int64

# %%
# export as pickle


df_new_ords_prods.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_produts_new_vars'))
